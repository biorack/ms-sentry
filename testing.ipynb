# %%
import ms_sentry_util
import pandas as pd

# %%
jgi_test_filenames = pd.read_csv('test_data/jgi_filenames.csv')
egsb_test_filenames = pd.read_csv('test_data/jgi_filenames.csv')

# %% [markdown]
# JGI Name Test

# %%
for idx, row in egsb_test_filenames.iterrows():
    category = ms_sentry_util._get_file_category(row['filename'])
    
    if category != row['category']:
        print('-------------------------------------')
        print(False)
        print('returned category: ' + category)
        print('actual category: ' + row['category'])
        print('-------------------------------------')
        
    else:
        print(True)
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %% [markdown]
# EGSB Name Test

# %%
name = '20220527_JGI_KD_507977_SoilCell_pilot_QE-HF_HILICZ_USHXG01885_FPS_MS1_0_InjBL-MeOH_Pre_Rg70to1050-CE102040--InjBL-MeOH_Run2.raw'

# %%
filename_categories_vocab = ['ISTD', 'QC', 'InjBL-MeOH']

filename_category_str = 'S1'
group_field = name.split('_')[12]
optional_field = name.split('_')[14]

optional_category_ele = [ele for ele in filename_categories_vocab if (ele in optional_field)]

# %%
print(optional_category_ele)
